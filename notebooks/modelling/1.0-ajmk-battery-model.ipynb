# %%
import pandas as pd
import seaborn as sns

# %%
lagged_data = pd.read_csv("/Users/alexanderkell/Documents/PhD/Projects/18-battery-optimisation/data/processed/lagged_2012-2013-solar-electricity-data.csv")
lagged_data
# Out:
#         Unnamed: 0  Unnamed: 0.1  Customer  Generator Capacity  Postcode  \
# 0               93            93         1                3.78      2076
# 1               94            94         1                3.78      2076
# 2               95            95         1                3.78      2076
# 3             9705        268650         1                3.78      2076
# 4             9706        268651         1                3.78      2076
# ...            ...           ...       ...                 ...       ...
# 198424      436621      12089146         4                1.00      2220
# 198425      436622      12089147         4                1.00      2220
# 198426      446232      12357702         4                1.00      2220
# 198427      446233      12357703         4                1.00      2220
# 198428      446234      12357704         4                1.00      2220
#
#                    Consumption Category        date   time  consumption  \
# ...

# %%
lagged_data.groupby("Consumption Category").max()
# Out:
#                                  Unnamed: 0  Unnamed: 0.1  Customer  \
# Consumption Category
# controlled_load_consumption          455898      12626313         4
# general_electricity_consumption      455899      12626314         4
# solar_generation                     455900      12626315         4
#
#                                  Generator Capacity  Postcode       date  \
# Consumption Category
# controlled_load_consumption                    3.78      2263  9/12/2012
# general_electricity_consumption                3.78      2263  9/12/2012
# solar_generation                               3.78      2263  9/12/2012
#
#                                  time  consumption             datetime  \
# Consumption Category
# controlled_load_consumption      9:30        3.196  2013-12-06 23:30:00
# general_electricity_consumption  9:30        2.979  2013-12-06 23:30:00
# solar_generation                 9:30        1.875  2013-12-06 23:30:00
#
# ...

# %%
sns.lineplot(data=lagged_data[(lagged_data.Customer==1) & (lagged_data.datetime>"2012-01-08") & (lagged_data.datetime<="2012-01-09")], x='datetime', y="consumption", hue="Consumption Category")
